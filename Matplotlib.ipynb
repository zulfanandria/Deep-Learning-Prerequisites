# %% [markdown]
# <a href="https://colab.research.google.com/github/zulfanandria/Deep-Learning-Prerequisites/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Line Chart

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 20, 1000)

# %%
y = np.sin(x) + 0.2 * x

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('My Plot');

# %% [markdown]
# #Scatterplot

# %%
x = np.random.randn(100, 2)
plt.scatter(x[:,0], x[:,1]);

# %%
x = np.random.randn(200, 2)
x[:50] += 3
y = np.zeros(200)
y[:50] = 1
plt.scatter(x[:,0], x[:,1], c=y);

# %% [markdown]
# # Histogram

# %%
x = np.random.randn(10000)

# %%
plt.hist(x);

# %%
plt.hist(x, bins=50);

# %%
x = np.random.random(10000)
plt.hist(x, bins=50);

# %% [markdown]
# # Plotting Images

# %%
# !wget https://www.zubludiving.com/images/Indonesia/West-Papua/Raja-Ampat/Raja-Ampat-Wayag-Diving.jpg
# Out:
# --2022-07-13 23:49:48--  https://www.zubludiving.com/images/Indonesia/West-Papua/Raja-Ampat/Raja-Ampat-Wayag-Diving.jpg
# Resolving www.zubludiving.com (www.zubludiving.com)... 104.26.10.30, 172.67.72.50, 104.26.11.30, ...
# Connecting to www.zubludiving.com (www.zubludiving.com)|104.26.10.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2147743 (2.0M) [image/jpeg]
# Saving to: ‘Raja-Ampat-Wayag-Diving.jpg’
#
# Raja-Ampat-Wayag-Di 100%[===================>]   2.05M  --.-KB/s    in 0.04s
#
# 2022-07-13 23:49:48 (56.9 MB/s) - ‘Raja-Ampat-Wayag-Diving.jpg’ saved [2147743/2147743]

# %%
from PIL import Image

# %%
im = Image.open('Raja-Ampat-Wayag-Diving.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr = np.array(im)
arr
# Out:
# array([[[ 42,  98, 183],
#         [ 43,  99, 182],
#         [ 45, 101, 184],
#         ...,
#         [ 57, 117, 205],
#         [ 58, 118, 206],
#         [ 58, 118, 206]],
#
#        [[ 42,  98, 181],
#         [ 43, 100, 181],
#         [ 44, 101, 182],
#         ...,
#         [ 59, 119, 207],
#         [ 57, 117, 205],
#         [ 57, 117, 205]],
#
#        [[ 44, 100, 183],
#         [ 44, 100, 183],
#         [ 43,  99, 182],
#         ...,
#         [ 58, 118, 204],
#         [ 58, 118, 204],
#         [ 58, 118, 206]],
#
#        ...,
#
#        [[116, 149,  58],
#         [ 41,  55,  22],
#         [ 72,  76,  26],
#         ...,
#         [202, 208, 120],
#         [188, 182,  72],
#         [186, 168,  66]],
#
#        [[ 58,  99,  43],
#         [ 65,  73,  32],
#         [ 60,  74,  23],
#         ...,
#         [212, 194, 118],
#         [183, 147,  63],
#         [155, 198,  83]],
#
#        [[ 61, 137,  46],
#         [ 44,  57,  29],
#         [ 41,  39,  18],
#         ...,
#         [197, 159,  86],
#         [190, 155,  73],
#         [182, 220, 137]]], dtype=uint8)

# %%
arr.shape
# Out:
# (900, 1600, 3)

# %%
plt.imshow(arr)

# %%
plt.imshow(im);

# %%
gray = arr.mean(axis=2)

# %%
gray.shape
# Out:
# (900, 1600)

# %%
plt.imshow(gray);

# %%
plt.imshow(gray, cmap='gray');
